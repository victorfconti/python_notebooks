# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
salario = np.array([1,2,3])

# %%
plt.plot(salario)

# %%
plt.plot(salario, c='Black')

# %%
aumentos = [100, 200, 550, 200, 100]
plt.plot(aumentos, c='Green', ls='--', marker='s')
plt.show()
